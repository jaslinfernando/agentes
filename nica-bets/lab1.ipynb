# %% [markdown]
# # Agentic AI --> nica-bets

# %%
# First let's do an import. If you get an Import Error, double check that your Kernel is correct..

from dotenv import load_dotenv

# %%
# Next it's time to load the API keys into environment variables
# If this returns false, see the next cell!

load_dotenv(override=True)
# Out:
# True

# %%
from bets import User

jaslin = User.get("jaslin")
jaslin

lieserl = User.get("lieserl")
lieserl

geli = User.get("geli")
geli


#account.place_bet("jaslin", "soccer",5)
# Out:
# User(username='geli', initial_deposit=100.0, balance=100.0, bets=[], holdings={}, strategy='', portfolio_value_time_series=[])

# %%
jaslin = User.get("jaslin")
jaslin
# Out:
# User(username='Jaslin', initial_deposit=100.0, balance=300.0, bets=[Bet(username='Jaslin', momio=Momio(game=Game(local_team=Team(name='FC Barcelona', sport=Sport(name='soccer')), visit_team=Team(name='Eintracht Frankfurt', sport=Sport(name='soccer')), final_score='', winner_team=Team(name='', sport=Sport(name='soccer'))), bet_type='Moneyline', local_momio=2.0, visit_momio=1.0, draw_momio=0.0), chosen_team=Team(name='FC Barcelona', sport=Sport(name='soccer')), bet_amount=100.0, status='Pending', total_profit=0.0, net_profit_amount=0.0, rationale='Betting on Barcelona to win at home.', bet_id='a5bde9b4-8a3c-4824-ae2c-6b62bd110bd8'), Bet(username='Jaslin', momio=Momio(game=Game(local_team=Team(name='Atalanta', sport=Sport(name='soccer')), visit_team=Team(name='Chelsea', sport=Sport(name='soccer')), final_score='', winner_team=Team(name='', sport=Sport(name='soccer'))), bet_type='Moneyline', local_momio=2.5, visit_momio=1.0, draw_momio=0.0), chosen_team=Team(name='Atalanta', sport=Sport(name='soccer')), bet_amount=100.0, status='Pending', total_profit=0.0, net_profit_amount=0.0, rationale='Atalanta has had strong home performances and Chelsea is struggling with form.', bet_id='5ec13dd3-2fe7-4a33-8363-9a9863ec3b8a'), Bet(username='Jaslin', momio=Momio(game=Game(local_team=Team(name='Bayern Munich', sport=Sport(name='soccer')), visit_team=Team(name='Sporting CP', sport=Sport(name='soccer')), final_score='', winner_team=Team(name='', sport=Sport(name='soccer'))), bet_type='Moneyline', local_momio=1.8, visit_momio=1.0, draw_momio=0.0), chosen_team=Team(name='Bayern Munich', sport=Sport(name='soccer')), bet_amount=100.0, status='Pending', total_profit=0.0, net_profit_amount=0.0, rationale='Bayern is historically strong at home against Sporting CP.', bet_id='d255a84d-8f75-4a89-b42a-014392248da9'), Bet(username='Jaslin', momio=Momio(game=Game(local_team=Team(name='FC Barcelona', sport=Sport(name='soccer')), visit_team=Team(name='Eintracht Frankfurt', sport=Sport(name='soccer')), final_score='', winner_team=Team(name='FC Barcelona', sport=Sport(name='soccer'))), bet_type='Moneyline', local_momio=2.0, visit_momio=1.0, draw_momio=0.0), chosen_team=Team(name='FC Barcelona', sport=Sport(name='soccer')), bet_amount=100.0, status='Win', total_profit=200.0, net_profit_amount=100.0, rationale='Betting on Barcelona to win at home.', bet_id='a5bde9b4-8a3c-4824-ae2c-6b62bd110bd8')], holdings={'soccer': 200}, strategy='', portfolio_value_time_series=[('2025-11-27 18:30:38', 100.0), ('2025-11-27 18:32:37', 100.0), ('2025-11-27 18:32:37', 100.0), ('2025-11-27 18:32:40', 100.0), ('2025-11-27 18:37:05', 100.0), ('2025-11-27 18:38:37', 300.0)])

# %%
#from bets import BettingSystem
from bets import User,Sport,Team,Game,Momio
from datetime import datetime

jaslin = User.get("jaslin")

sport= Sport(name="soccer")

local_team = Team(name="Masachapa",sport=sport)
visit_team = Team(name="San Marcos",sport=sport)
final_score = "2-0"
date_time = datetime.now()
winner_team = Team(name="",sport=sport)#Masachapa equip que ha ganado


game = Game(local_team=local_team,visit_team=visit_team,final_score=final_score,winner_team=winner_team,date_time=date_time)

bet_type = "Moneyline"
local_momio= 2
visit_momio = 1
draw_momio = 0

momio =  Momio(game=game,bet_type=bet_type,local_momio=local_momio,visit_momio=visit_momio,draw_momio=draw_momio)

print(type(game))

bet_amount = 10
chosen_team = Team(name="Masachapa",sport=sport)


bet = jaslin.place_bet( "jaslin",momio,chosen_team=chosen_team,bet_amount=bet_amount, status="Pending", rationale= "Va a ganar el Masachapa FC por que es local")
bet

#lieserl
lieserl = User.get("lieserl")

sport= Sport(name="baseball")

local_team = Team(name="Boer",sport=sport)
visit_team = Team(name="'Gigantes de Rivas",sport=sport)
final_score = "6-5"
date_time = datetime.now()
winner_team = Team(name="",sport=sport)# Gigantes de Rivas equip que ha ganado


game = Game(local_team=local_team,visit_team=visit_team,final_score=final_score,winner_team=winner_team,date_time=date_time)

bet_type = "Over"
local_momio= 3
visit_momio = 2
draw_momio = 1

momio =  Momio(game=game,bet_type=bet_type,local_momio=local_momio,visit_momio=visit_momio,draw_momio=draw_momio)

print(type(game))

bet_amount = 20
chosen_team = Team(name="Boer",sport=sport)


bet = lieserl.place_bet( "lieserl",momio,chosen_team=chosen_team,bet_amount=bet_amount, status="Pending", rationale= "El Boer es el mejor equipo armado esta temporada 2025 en la liga profesional")
bet

#geli
geli = User.get("geli")

sport= Sport(name="basketball")

local_team = Team(name="Lakers",sport=sport)
visit_team = Team(name="'Miami Heat",sport=sport)
final_score = "90-95"
date_time = datetime.now()
winner_team = Team(name="",sport=sport)# Lakers equipo que ha ganado


game = Game(local_team=local_team,visit_team=visit_team,final_score=final_score,winner_team=winner_team,date_time=date_time)

bet_type = "Handicap"
local_momio= 7
visit_momio = 6
draw_momio = 5

momio =  Momio(game=game,bet_type=bet_type,local_momio=local_momio,visit_momio=visit_momio,draw_momio=draw_momio)

print(type(game))

bet_amount = 15
chosen_team = Team(name="Lakers",sport=sport)


bet = geli.place_bet( "geli",momio,chosen_team=chosen_team,bet_amount=bet_amount, status="Pending", rationale= "Los L.A Lakers tienen mejor equipo en el 2025")
bet
# Out:
# <class 'bets.Game'>
# <class 'bets.Game'>
# <class 'bets.Game'>
# 'Completed. Latest details:\n{"username": "geli", "initial_deposit": 100.0, "balance": 100.0, "bets": [{"username": "geli", "momio": {"game": {"local_team": {"name": "Lakers", "sport": {"name": "basketball"}}, "visit_team": {"name": "\'Miami Heat", "sport": {"name": "basketball"}}, "final_score": "90-95", "winner_team": {"name": "", "sport": {"name": "basketball"}}}, "bet_type": "Handicap", "local_momio": 7.0, "visit_momio": 6.0, "draw_momio": 5.0}, "chosen_team": {"name": "Lakers", "sport": {"name": "basketball"}}, "bet_amount": 15.0, "status": "Pending", "total_profit": 0.0, "net_profit_amount": 0.0, "rationale": "Los L.A Lakers tienen mejor equipo en el 2025", "bet_id": "b39a387c-8b02-4ba5-b910-e3b726ab6464"}], "holdings": {}, "strategy": "", "portfolio_value_time_series": [["2025-11-27 18:59:26", 100.0]], "total_portfolio_value": 100.0, "total_profit_loss": 0.0}'

# %%
from bets import User
#User.get("jaslin").report()
User.get("lieserl").report()
#User.get("geli").report()
# Out:
# '{"username": "lieserl", "initial_deposit": 100.0, "balance": 100.0, "bets": [{"username": "lieserl", "momio": {"game": {"local_team": {"name": "Boer", "sport": {"name": "baseball"}}, "visit_team": {"name": "\'Gigantes de Rivas", "sport": {"name": "baseball"}}, "final_score": "6-5", "winner_team": {"name": "", "sport": {"name": "baseball"}}}, "bet_type": "Over", "local_momio": 3.0, "visit_momio": 2.0, "draw_momio": 1.0}, "chosen_team": {"name": "Boer", "sport": {"name": "baseball"}}, "bet_amount": 20.0, "status": "Pending", "total_profit": 0.0, "net_profit_amount": 0.0, "rationale": "El Boer es el mejor equipo armado esta temporada 2025 en la liga profesional", "bet_id": "6ffb76e4-87cd-4025-9171-f9f319f481e2"}], "holdings": {}, "strategy": "", "portfolio_value_time_series": [["2025-11-27 18:59:26", 100.0], ["2025-11-27 19:06:40", 100.0], ["2025-11-27 19:07:02", 100.0], ["2025-11-27 19:10:12", 100.0]], "total_portfolio_value": 100.0, "total_profit_loss": 0.0}'

# %%
from bets import User
#mandamos El equipo y el resultado que tuvo ese equipo. Por ejemplo El Masachapa ganó
#User.get("jaslin").update_bet("jaslin","8bfd3a44-c171-4406-932e-159cdc544567","Masachapa", "Win")
User.get("lieserl").update_bet("lieserl","6ffb76e4-87cd-4025-9171-f9f319f481e2","Gigantes de Rivas", "Lose")
#User.get("geli").update_bet("geli","b39a387c-8b02-4ba5-b910-e3b726ab6464","Lakers", "Lose")
# Out:
# /Users/exjaflo/Documents/nisum/github/agentes/.venv/lib/python3.12/site-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `int` - serialized value may not be as expected [input_value=60.0, input_type=float])
#   return self.__pydantic_serializer__.to_python(
# '{"username": "lieserl", "initial_deposit": 100.0, "balance": 160.0, "bets": [{"username": "lieserl", "momio": {"game": {"local_team": {"name": "Boer", "sport": {"name": "baseball"}}, "visit_team": {"name": "\'Gigantes de Rivas", "sport": {"name": "baseball"}}, "final_score": "6-5", "winner_team": {"name": "Boer", "sport": {"name": "baseball"}}}, "bet_type": "Over", "local_momio": 3.0, "visit_momio": 2.0, "draw_momio": 1.0}, "chosen_team": {"name": "Boer", "sport": {"name": "baseball"}}, "bet_amount": 20.0, "status": "Win", "total_profit": 60.0, "net_profit_amount": 40.0, "rationale": "El Boer es el mejor equipo armado esta temporada 2025 en la liga profesional", "bet_id": "6ffb76e4-87cd-4025-9171-f9f319f481e2"}], "holdings": {"baseball": 60.0}, "strategy": "", "portfolio_value_time_series": [["2025-11-27 18:59:26", 100.0], ["2025-11-27 19:06:40", 100.0], ["2025-11-27 19:07:02", 100.0], ["2025-11-27 19:10:12", 100.0], ["2025-11-27 19:10:48", 160.0]], "total_portfolio_value": 160.0, "total_profit_loss": 60.0}'

# %%
from bets import User,Sport,Team,Game,Momio
from datetime import datetime

jaslin = User.get("jaslin")

sport= Sport(name="soccer")

local_team = Team(name="Spain",sport=sport)
visit_team = Team(name="'Argentina",sport=sport)
final_score = "1-0"
date_time = datetime.now()

winner_team = Team(name="",sport=sport)# Spain equip que ha ganado


game = Game(local_team=local_team,visit_team=visit_team,final_score=final_score,
            winner_team=winner_team
            ,date_time=date_time)

bet_type = "Moneyline"
local_momio= 2
visit_momio = 1
draw_momio = 0

momio =  Momio(game=game,bet_type=bet_type,local_momio=local_momio,visit_momio=visit_momio,draw_momio=draw_momio)

print(type(game))

bet_amount = 5
chosen_team = Team(name="Argentina",sport=sport)



bet = jaslin.place_bet( "jaslin",momio,chosen_team=chosen_team,bet_amount=bet_amount, status="Pending", rationale= "Argentina pasa por un buen momento este 2025")
bet
# Out:
# ***Getting name:jaslin
# <class 'bets.Game'>
# ***Getting name:jaslin
# json_data: {"username": "jaslin", "initial_deposit": 100.0, "balance": 120.0, "bets": [{"username": "jaslin", "momio": {"game": {"local_team": {"name": "Masachapa", "sport": {"name": "soccer"}}, "visit_team": {"name": "'San Marcos", "sport": {"name": "soccer"}}, "final_score": "2-0", "winner_team": {"name": "Masachapa", "sport": {"name": "soccer"}}}, "bet_type": "Moneyline", "local_momio": 2.0, "visit_momio": 1.0, "draw_momio": 0.0}, "chosen_team": {"name": "Masachapa", "sport": {"name": "soccer"}}, "bet_amount": 10.0, "status": "Win", "total_profit": 20.0, "net_profit_amount": 10.0, "rationale": "Va a ganar el Masachapa FC por que es local", "bet_id": "ee31d060-7d40-4541-8bb7-fe0541adb51f"}, {"username": "jaslin", "momio": {"game": {"local_team": {"name": "Spain", "sport": {"name": "soccer"}}, "visit_team": {"name": "'Argentina", "sport": {"name": "soccer"}}, "final_score": "1-0", "winner_team": {"name": "", "sport": {"name": "soccer"}}}, "bet_type": "Moneyline", "local_momio": 2.0, "visit_momio": 1.0, "draw_momio": 0.0}, "chosen_team": {"name": "Argentina", "sport": {"name": "soccer"}}, "bet_amount": 5.0, "status": "Pending", "total_profit": 0.0, "net_profit_amount": 0.0, "rationale": "Argentina pasa por un buen momento este 2025", "bet_id": "fd7e676b-3972-4ddc-8e6b-addf37194ccb"}], "holdings": {"soccer": 20}, "strategy": "", "portfolio_value_time_series": [["2025-11-27 08:28:25", 100.0], ["2025-11-27 08:29:09", 120.0], ["2025-11-27 08:30:08", 120.0]]}
# 'Completed. Latest details:\n{"username": "jaslin", "initial_deposit": 100.0, "balance": 120.0, "bets": [{"username": "jaslin", "momio": {"game": {"local_team": {"name": "Masachapa", "sport": {"name": "soccer"}}, "visit_team": {"name": "\'San Marcos", "sport": {"name": "soccer"}}, "final_score": "2-0", "winner_team": {"name": "Masachapa", "sport": {"name": "soccer"}}}, "bet_type": "Moneyline", "local_momio": 2.0, "visit_momio": 1.0, "draw_momio": 0.0}, "chosen_team": {"name": "Masachapa", "sport": {"name": "soccer"}}, "bet_amount": 10.0, "status": "Win", "total_profit": 20.0, "net_profit_amount": 10.0, "rationale": "Va a ganar el Masachapa FC por que es local", "bet_id": "ee31d060-7d40-4541-8bb7-fe0541adb51f"}, {"username": "jaslin", "momio": {"game": {"local_team": {"name": "Spain", "sport": {"name": "soccer"}}, "visit_team": {"name": "\'Argentina", "sport": {"name": "soccer"}}, "final_score": "1-0", "winner_team": {"name": "", "sport": {"name": "soccer"}}}, "bet_type": "Moneyline", "local_momio": 2.0, "visit_momio": 1.0, "draw_momio": 0.0}, "chosen_team": {"name": "Argentina", "sport": {"name": "soccer"}}, "bet_amount": 5.0, "status": "Pending", "total_profit": 0.0, "net_profit_amount": 0.0, "rationale": "Argentina pasa por un buen momento este 2025", "bet_id": "fd7e676b-3972-4ddc-8e6b-addf37194ccb"}], "holdings": {"soccer": 20}, "strategy": "", "portfolio_value_time_series": [["2025-11-27 08:28:25", 100.0], ["2025-11-27 08:29:09", 120.0], ["2025-11-27 08:30:08", 120.0]], "total_portfolio_value": 120.0, "total_profit_loss": 20.0}'

# %%
jaslin.update_bet("jaslin","fd7e676b-3972-4ddc-8e6b-addf37194ccb","Spain", "Win")
# Out:
# ***Getting name:jaslin
# json_data: {"username": "jaslin", "initial_deposit": 100.0, "balance": 115.0, "bets": [{"username": "jaslin", "momio": {"game": {"local_team": {"name": "Masachapa", "sport": {"name": "soccer"}}, "visit_team": {"name": "'San Marcos", "sport": {"name": "soccer"}}, "final_score": "2-0", "winner_team": {"name": "Masachapa", "sport": {"name": "soccer"}}}, "bet_type": "Moneyline", "local_momio": 2.0, "visit_momio": 1.0, "draw_momio": 0.0}, "chosen_team": {"name": "Masachapa", "sport": {"name": "soccer"}}, "bet_amount": 10.0, "status": "Win", "total_profit": 20.0, "net_profit_amount": 10.0, "rationale": "Va a ganar el Masachapa FC por que es local", "bet_id": "ee31d060-7d40-4541-8bb7-fe0541adb51f"}, {"username": "jaslin", "momio": {"game": {"local_team": {"name": "Spain", "sport": {"name": "soccer"}}, "visit_team": {"name": "'Argentina", "sport": {"name": "soccer"}}, "final_score": "1-0", "winner_team": {"name": "Spain", "sport": {"name": "soccer"}}}, "bet_type": "Moneyline", "local_momio": 2.0, "visit_momio": 1.0, "draw_momio": 0.0}, "chosen_team": {"name": "Argentina", "sport": {"name": "soccer"}}, "bet_amount": 5.0, "status": "Lose", "total_profit": 0.0, "net_profit_amount": 0.0, "rationale": "Argentina pasa por un buen momento este 2025", "bet_id": "fd7e676b-3972-4ddc-8e6b-addf37194ccb"}], "holdings": {"soccer": 15.0}, "strategy": "", "portfolio_value_time_series": [["2025-11-27 08:28:25", 100.0], ["2025-11-27 08:29:09", 120.0], ["2025-11-27 08:30:08", 120.0]]}
# json_data: {"username": "jaslin", "initial_deposit": 100.0, "balance": 115.0, "bets": [{"username": "jaslin", "momio": {"game": {"local_team": {"name": "Masachapa", "sport": {"name": "soccer"}}, "visit_team": {"name": "'San Marcos", "sport": {"name": "soccer"}}, "final_score": "2-0", "winner_team": {"name": "Masachapa", "sport": {"name": "soccer"}}}, "bet_type": "Moneyline", "local_momio": 2.0, "visit_momio": 1.0, "draw_momio": 0.0}, "chosen_team": {"name": "Masachapa", "sport": {"name": "soccer"}}, "bet_amount": 10.0, "status": "Win", "total_profit": 20.0, "net_profit_amount": 10.0, "rationale": "Va a ganar el Masachapa FC por que es local", "bet_id": "ee31d060-7d40-4541-8bb7-fe0541adb51f"}, {"username": "jaslin", "momio": {"game": {"local_team": {"name": "Spain", "sport": {"name": "soccer"}}, "visit_team": {"name": "'Argentina", "sport": {"name": "soccer"}}, "final_score": "1-0", "winner_team": {"name": "Spain", "sport": {"name": "soccer"}}}, "bet_type": "Moneyline", "local_momio": 2.0, "visit_momio": 1.0, "draw_momio": 0.0}, "chosen_team": {"name": "Argentina", "sport": {"name": "soccer"}}, "bet_amount": 5.0, "status": "Lose", "total_profit": 0.0, "net_profit_amount": 0.0, "rationale": "Argentina pasa por un buen momento este 2025", "bet_id": "fd7e676b-3972-4ddc-8e6b-addf37194ccb"}], "holdings": {"soccer": 15.0}, "strategy": "", "portfolio_value_time_series": [["2025-11-27 08:28:25", 100.0], ["2025-11-27 08:29:09", 120.0], ["2025-11-27 08:30:08", 120.0], ["2025-11-27 08:31:18", 115.0]]}
# /Users/exjaflo/Documents/nisum/github/agentes/.venv/lib/python3.12/site-packages/pydantic/main.py:463: UserWarning: Pydantic serializer warnings:
#   PydanticSerializationUnexpectedValue(Expected `int` - serialized value may not be as expected [input_value=15.0, input_type=float])
#   return self.__pydantic_serializer__.to_python(
# '{"username": "jaslin", "initial_deposit": 100.0, "balance": 115.0, "bets": [{"username": "jaslin", "momio": {"game": {"local_team": {"name": "Masachapa", "sport": {"name": "soccer"}}, "visit_team": {"name": "\'San Marcos", "sport": {"name": "soccer"}}, "final_score": "2-0", "winner_team": {"name": "Masachapa", "sport": {"name": "soccer"}}}, "bet_type": "Moneyline", "local_momio": 2.0, "visit_momio": 1.0, "draw_momio": 0.0}, "chosen_team": {"name": "Masachapa", "sport": {"name": "soccer"}}, "bet_amount": 10.0, "status": "Win", "total_profit": 20.0, "net_profit_amount": 10.0, "rationale": "Va a ganar el Masachapa FC por que es local", "bet_id": "ee31d060-7d40-4541-8bb7-fe0541adb51f"}, {"username": "jaslin", "momio": {"game": {"local_team": {"name": "Spain", "sport": {"name": "soccer"}}, "visit_team": {"name": "\'Argentina", "sport": {"name": "soccer"}}, "final_score": "1-0", "winner_team": {"name": "Spain", "sport": {"name": "soccer"}}}, "bet_type": "Moneyline", "local_momio": 2.0, "visit_momio": 1.0, "draw_momio": 0.0}, "chosen_team": {"name": "Argentina", "sport": {"name": "soccer"}}, "bet_amount": 5.0, "status": "Lose", "total_profit": 0.0, "net_profit_amount": 0.0, "rationale": "Argentina pasa por un buen momento este 2025", "bet_id": "fd7e676b-3972-4ddc-8e6b-addf37194ccb"}], "holdings": {"soccer": 15.0}, "strategy": "", "portfolio_value_time_series": [["2025-11-27 08:28:25", 100.0], ["2025-11-27 08:29:09", 120.0], ["2025-11-27 08:30:08", 120.0], ["2025-11-27 08:31:18", 115.0]], "total_portfolio_value": 115.0, "total_profit_loss": 15.0}'

# %%
#jaslin
jaslin = User.get("jaslin")

sport= Sport(name="baseball")

local_team = Team(name="Boer",sport=sport)
visit_team = Team(name="'San Fernando",sport=sport)
final_score = "8-1"
date_time = datetime.now()
winner_team = Team(name="",sport=sport)# Boer equip que ha ganado


game = Game(local_team=local_team,visit_team=visit_team,final_score=final_score,winner_team=local_team,date_time=date_time)

bet_type = "Under"
local_momio= 1
visit_momio = 3
draw_momio = 4

momio =  Momio(game=game,bet_type=bet_type,local_momio=local_momio,visit_momio=visit_momio,draw_momio=draw_momio)

print(type(game))

bet_amount = 20
chosen_team = Team(name="Boer",sport=sport)


bet = jaslin.place_bet( "jaslin",momio,chosen_team=chosen_team,bet_amount=bet_amount, status="Pending", rationale= "El Boer es el mejor equipo armado esta temporada 2025 en la liga profesional")
bet
# Out:
# ***Getting name:jaslin
# <class 'bets.Game'>
# ***Getting name:jaslin
# json_data: {"username": "jaslin", "initial_deposit": 100.0, "balance": 115.0, "bets": [{"username": "jaslin", "momio": {"game": {"local_team": {"name": "Masachapa", "sport": {"name": "soccer"}}, "visit_team": {"name": "'San Marcos", "sport": {"name": "soccer"}}, "final_score": "2-0", "winner_team": {"name": "Masachapa", "sport": {"name": "soccer"}}}, "bet_type": "Moneyline", "local_momio": 2.0, "visit_momio": 1.0, "draw_momio": 0.0}, "chosen_team": {"name": "Masachapa", "sport": {"name": "soccer"}}, "bet_amount": 10.0, "status": "Win", "total_profit": 20.0, "net_profit_amount": 10.0, "rationale": "Va a ganar el Masachapa FC por que es local", "bet_id": "ee31d060-7d40-4541-8bb7-fe0541adb51f"}, {"username": "jaslin", "momio": {"game": {"local_team": {"name": "Spain", "sport": {"name": "soccer"}}, "visit_team": {"name": "'Argentina", "sport": {"name": "soccer"}}, "final_score": "1-0", "winner_team": {"name": "Spain", "sport": {"name": "soccer"}}}, "bet_type": "Moneyline", "local_momio": 2.0, "visit_momio": 1.0, "draw_momio": 0.0}, "chosen_team": {"name": "Argentina", "sport": {"name": "soccer"}}, "bet_amount": 5.0, "status": "Lose", "total_profit": 0.0, "net_profit_amount": 0.0, "rationale": "Argentina pasa por un buen momento este 2025", "bet_id": "fd7e676b-3972-4ddc-8e6b-addf37194ccb"}, {"username": "jaslin", "momio": {"game": {"local_team": {"name": "Boer", "sport": {"name": "baseball"}}, "visit_team": {"name": "'San Fernando", "sport": {"name": "baseball"}}, "final_score": "8-1", "winner_team": {"name": "Boer", "sport": {"name": "baseball"}}}, "bet_type": "Under", "local_momio": 1.0, "visit_momio": 3.0, "draw_momio": 4.0}, "chosen_team": {"name": "Boer", "sport": {"name": "baseball"}}, "bet_amount": 20.0, "status": "Pending", "total_profit": 0.0, "net_profit_amount": 0.0, "rationale": "El Boer es el mejor equipo armado esta temporada 2025 en la liga profesional", "bet_id": "6338cb8f-1c6d-4298-8551-c10703e5caa7"}], "holdings": {"soccer": 15}, "strategy": "", "portfolio_value_time_series": [["2025-11-27 08:28:25", 100.0], ["2025-11-27 08:29:09", 120.0], ["2025-11-27 08:30:08", 120.0], ["2025-11-27 08:31:18", 115.0], ["2025-11-27 08:31:41", 115.0]]}
# 'Completed. Latest details:\n{"username": "jaslin", "initial_deposit": 100.0, "balance": 115.0, "bets": [{"username": "jaslin", "momio": {"game": {"local_team": {"name": "Masachapa", "sport": {"name": "soccer"}}, "visit_team": {"name": "\'San Marcos", "sport": {"name": "soccer"}}, "final_score": "2-0", "winner_team": {"name": "Masachapa", "sport": {"name": "soccer"}}}, "bet_type": "Moneyline", "local_momio": 2.0, "visit_momio": 1.0, "draw_momio": 0.0}, "chosen_team": {"name": "Masachapa", "sport": {"name": "soccer"}}, "bet_amount": 10.0, "status": "Win", "total_profit": 20.0, "net_profit_amount": 10.0, "rationale": "Va a ganar el Masachapa FC por que es local", "bet_id": "ee31d060-7d40-4541-8bb7-fe0541adb51f"}, {"username": "jaslin", "momio": {"game": {"local_team": {"name": "Spain", "sport": {"name": "soccer"}}, "visit_team": {"name": "\'Argentina", "sport": {"name": "soccer"}}, "final_score": "1-0", "winner_team": {"name": "Spain", "sport": {"name": "soccer"}}}, "bet_type": "Moneyline", "local_momio": 2.0, "visit_momio": 1.0, "draw_momio": 0.0}, "chosen_team": {"name": "Argentina", "sport": {"name": "soccer"}}, "bet_amount": 5.0, "status": "Lose", "total_profit": 0.0, "net_profit_amount": 0.0, "rationale": "Argentina pasa por un buen momento este 2025", "bet_id": "fd7e676b-3972-4ddc-8e6b-addf37194ccb"}, {"username": "jaslin", "momio": {"game": {"local_team": {"name": "Boer", "sport": {"name": "baseball"}}, "visit_team": {"name": "\'San Fernando", "sport": {"name": "baseball"}}, "final_score": "8-1", "winner_team": {"name": "Boer", "sport": {"name": "baseball"}}}, "bet_type": "Under", "local_momio": 1.0, "visit_momio": 3.0, "draw_momio": 4.0}, "chosen_team": {"name": "Boer", "sport": {"name": "baseball"}}, "bet_amount": 20.0, "status": "Pending", "total_profit": 0.0, "net_profit_amount": 0.0, "rationale": "El Boer es el mejor equipo armado esta temporada 2025 en la liga profesional", "bet_id": "6338cb8f-1c6d-4298-8551-c10703e5caa7"}], "holdings": {"soccer": 15}, "strategy": "", "portfolio_value_time_series": [["2025-11-27 08:28:25", 100.0], ["2025-11-27 08:29:09", 120.0], ["2025-11-27 08:30:08", 120.0], ["2025-11-27 08:31:18", 115.0], ["2025-11-27 08:31:41", 115.0]], "total_portfolio_value": 115.0, "total_profit_loss": 15.0}'

# %%
jaslin.update_bet("jaslin","6338cb8f-1c6d-4298-8551-c10703e5caa7","Boer", "Win")
# Out:
# ***Getting name:jaslin
# ***Win total_profit:20.0 = 20.0*1.0
# *** updating bet total_profit:0.0 = 20.0*1.0
# json_data: {"username": "jaslin", "initial_deposit": 100.0, "balance": 135.0, "bets": [{"username": "jaslin", "momio": {"game": {"local_team": {"name": "Masachapa", "sport": {"name": "soccer"}}, "visit_team": {"name": "'San Marcos", "sport": {"name": "soccer"}}, "final_score": "2-0", "winner_team": {"name": "Masachapa", "sport": {"name": "soccer"}}}, "bet_type": "Moneyline", "local_momio": 2.0, "visit_momio": 1.0, "draw_momio": 0.0}, "chosen_team": {"name": "Masachapa", "sport": {"name": "soccer"}}, "bet_amount": 10.0, "status": "Win", "total_profit": 20.0, "net_profit_amount": 10.0, "rationale": "Va a ganar el Masachapa FC por que es local", "bet_id": "ee31d060-7d40-4541-8bb7-fe0541adb51f"}, {"username": "jaslin", "momio": {"game": {"local_team": {"name": "Spain", "sport": {"name": "soccer"}}, "visit_team": {"name": "'Argentina", "sport": {"name": "soccer"}}, "final_score": "1-0", "winner_team": {"name": "Spain", "sport": {"name": "soccer"}}}, "bet_type": "Moneyline", "local_momio": 2.0, "visit_momio": 1.0, "draw_momio": 0.0}, "chosen_team": {"name": "Argentina", "sport": {"name": "soccer"}}, "bet_amount": 5.0, "status": "Lose", "total_profit": 0.0, "net_profit_amount": 0.0, "rationale": "Argentina pasa por un buen momento este 2025", "bet_id": "fd7e676b-3972-4ddc-8e6b-addf37194ccb"}, {"username": "jaslin", "momio": {"game": {"local_team": {"name": "Boer", "sport": {"name": "baseball"}}, "visit_team": {"name": "'San Fernando", "sport": {"name": "baseball"}}, "final_score": "8-1", "winner_team": {"name": "Boer", "sport": {"name": "baseball"}}}, "bet_type": "Under", "local_momio": 1.0, "visit_momio": 3.0, "draw_momio": 4.0}, "chosen_team": {"name": "Boer", "sport": {"name": "baseball"}}, "bet_amount": 20.0, "status": "Win", "total_profit": 20.0, "net_profit_amount": 0.0, "rationale": "El Boer es el mejor equipo armado esta temporada 2025 en la liga profesional", "bet_id": "6338cb8f-1c6d-4298-8551-c10703e5caa7"}], "holdings": {"soccer": 15, "baseball": 20.0}, "strategy": "", "portfolio_value_time_series": [["2025-11-27 08:28:25", 100.0], ["2025-11-27 08:29:09", 120.0], ["2025-11-27 08:30:08", 120.0], ["2025-11-27 08:31:18", 115.0], ["2025-11-27 08:31:41", 115.0]]}
# json_data: {"username": "jaslin", "initial_deposit": 100.0, "balance": 135.0, "bets": [{"username": "jaslin", "momio": {"game": {"local_team": {"name": "Masachapa", "sport": {"name": "soccer"}}, "visit_team": {"name": "'San Marcos", "sport": {"name": "soccer"}}, "final_score": "2-0", "winner_team": {"name": "Masachapa", "sport": {"name": "soccer"}}}, "bet_type": "Moneyline", "local_momio": 2.0, "visit_momio": 1.0, "draw_momio": 0.0}, "chosen_team": {"name": "Masachapa", "sport": {"name": "soccer"}}, "bet_amount": 10.0, "status": "Win", "total_profit": 20.0, "net_profit_amount": 10.0, "rationale": "Va a ganar el Masachapa FC por que es local", "bet_id": "ee31d060-7d40-4541-8bb7-fe0541adb51f"}, {"username": "jaslin", "momio": {"game": {"local_team": {"name": "Spain", "sport": {"name": "soccer"}}, "visit_team": {"name": "'Argentina", "sport": {"name": "soccer"}}, "final_score": "1-0", "winner_team": {"name": "Spain", "sport": {"name": "soccer"}}}, "bet_type": "Moneyline", "local_momio": 2.0, "visit_momio": 1.0, "draw_momio": 0.0}, "chosen_team": {"name": "Argentina", "sport": {"name": "soccer"}}, "bet_amount": 5.0, "status": "Lose", "total_profit": 0.0, "net_profit_amount": 0.0, "rationale": "Argentina pasa por un buen momento este 2025", "bet_id": "fd7e676b-3972-4ddc-8e6b-addf37194ccb"}, {"username": "jaslin", "momio": {"game": {"local_team": {"name": "Boer", "sport": {"name": "baseball"}}, "visit_team": {"name": "'San Fernando", "sport": {"name": "baseball"}}, "final_score": "8-1", "winner_team": {"name": "Boer", "sport": {"name": "baseball"}}}, "bet_type": "Under", "local_momio": 1.0, "visit_momio": 3.0, "draw_momio": 4.0}, "chosen_team": {"name": "Boer", "sport": {"name": "baseball"}}, "bet_amount": 20.0, "status": "Win", "total_profit": 20.0, "net_profit_amount": 0.0, "rationale": "El Boer es el mejor equipo armado esta temporada 2025 en la liga profesional", "bet_id": "6338cb8f-1c6d-4298-8551-c10703e5caa7"}], "holdings": {"soccer": 15, "baseball": 20.0}, "strategy": "", "portfolio_value_time_series": [["2025-11-27 08:28:25", 100.0], ["2025-11-27 08:29:09", 120.0], ["2025-11-27 08:30:08", 120.0], ["2025-11-27 08:31:18", 115.0], ["2025-11-27 08:31:41", 115.0], ["2025-11-27 08:32:11", 135.0]]}
# '{"username": "jaslin", "initial_deposit": 100.0, "balance": 135.0, "bets": [{"username": "jaslin", "momio": {"game": {"local_team": {"name": "Masachapa", "sport": {"name": "soccer"}}, "visit_team": {"name": "\'San Marcos", "sport": {"name": "soccer"}}, "final_score": "2-0", "winner_team": {"name": "Masachapa", "sport": {"name": "soccer"}}}, "bet_type": "Moneyline", "local_momio": 2.0, "visit_momio": 1.0, "draw_momio": 0.0}, "chosen_team": {"name": "Masachapa", "sport": {"name": "soccer"}}, "bet_amount": 10.0, "status": "Win", "total_profit": 20.0, "net_profit_amount": 10.0, "rationale": "Va a ganar el Masachapa FC por que es local", "bet_id": "ee31d060-7d40-4541-8bb7-fe0541adb51f"}, {"username": "jaslin", "momio": {"game": {"local_team": {"name": "Spain", "sport": {"name": "soccer"}}, "visit_team": {"name": "\'Argentina", "sport": {"name": "soccer"}}, "final_score": "1-0", "winner_team": {"name": "Spain", "sport": {"name": "soccer"}}}, "bet_type": "Moneyline", "local_momio": 2.0, "visit_momio": 1.0, "draw_momio": 0.0}, "chosen_team": {"name": "Argentina", "sport": {"name": "soccer"}}, "bet_amount": 5.0, "status": "Lose", "total_profit": 0.0, "net_profit_amount": 0.0, "rationale": "Argentina pasa por un buen momento este 2025", "bet_id": "fd7e676b-3972-4ddc-8e6b-addf37194ccb"}, {"username": "jaslin", "momio": {"game": {"local_team": {"name": "Boer", "sport": {"name": "baseball"}}, "visit_team": {"name": "\'San Fernando", "sport": {"name": "baseball"}}, "final_score": "8-1", "winner_team": {"name": "Boer", "sport": {"name": "baseball"}}}, "bet_type": "Under", "local_momio": 1.0, "visit_momio": 3.0, "draw_momio": 4.0}, "chosen_team": {"name": "Boer", "sport": {"name": "baseball"}}, "bet_amount": 20.0, "status": "Win", "total_profit": 20.0, "net_profit_amount": 0.0, "rationale": "El Boer es el mejor equipo armado esta temporada 2025 en la liga profesional", "bet_id": "6338cb8f-1c6d-4298-8551-c10703e5caa7"}], "holdings": {"soccer": 15, "baseball": 20.0}, "strategy": "", "portfolio_value_time_series": [["2025-11-27 08:28:25", 100.0], ["2025-11-27 08:29:09", 120.0], ["2025-11-27 08:30:08", 120.0], ["2025-11-27 08:31:18", 115.0], ["2025-11-27 08:31:41", 115.0], ["2025-11-27 08:32:11", 135.0]], "total_portfolio_value": 135.0, "total_profit_loss": 35.0}'

# %%
from agents.mcp import MCPServerStdio

params = {"command": "uv", "args": ["run", "bets_server.py"]}
async with MCPServerStdio(params=params, client_session_timeout_seconds=30) as server:
    mcp_tools = await server.list_tools()

mcp_tools
# Out:
# [Tool(name='get_holdings', title=None, description='Get the holdings of the given account name.\n\n    Args:\n        name: The name of the account holder\n    ', inputSchema={'properties': {'name': {'title': 'Name', 'type': 'string'}}, 'required': ['name'], 'title': 'get_holdingsArguments', 'type': 'object'}, outputSchema={'additionalProperties': {'type': 'integer'}, 'title': 'get_holdingsDictOutput', 'type': 'object'}, icons=None, annotations=None, meta=None)]

# %%
from bets_client import get_bets_tools_openai, list_bets_tools,read_accounts_resource

mcp_tools = await list_bets_tools()
print(mcp_tools)

openai_tools = await get_bets_tools_openai()
print(openai_tools)
# Out:
# [Tool(name='get_holdings', title=None, description='Get the holdings of the given account name.\n\n    Args:\n        name: The name of the account holder\n    ', inputSchema={'properties': {'name': {'title': 'Name', 'type': 'string'}}, 'required': ['name'], 'title': 'get_holdingsArguments', 'type': 'object'}, outputSchema={'additionalProperties': {'type': 'integer'}, 'title': 'get_holdingsDictOutput', 'type': 'object'}, icons=None, annotations=None, meta=None)]
# [FunctionTool(name='get_holdings', description='Get the holdings of the given account name.\n\n    Args:\n        name: The name of the account holder\n    ', params_json_schema={'properties': {'name': {'title': 'Name', 'type': 'string'}}, 'required': ['name'], 'title': 'get_holdingsArguments', 'type': 'object', 'additionalProperties': False}, on_invoke_tool=<function get_bets_tools_openai.<locals>.<lambda> at 0x10629bba0>, strict_json_schema=True, is_enabled=True, tool_input_guardrails=None, tool_output_guardrails=None)]

# %%
from bets_client import read_accounts_resource,read_strategy_resource
from bets import User

context = await read_accounts_resource("jaslin")
print(context)

jaslin = User.get("jaslin")
jaslin.change_strategy("Randmon")

strategy = await read_strategy_resource("jaslin")
print(strategy)

lieserl = User.get("lieserl")
lieserl.change_strategy("Optimistic")

strategy = await read_strategy_resource("lieserl")
print(strategy)

geli = User.get("geli")
geli.change_strategy("Pessimistic")

strategy = await read_strategy_resource("geli")
print(strategy)
# Out:
# {"username": "jaslin", "initial_deposit": 100.0, "balance": 135.0, "bets": [{"username": "jaslin", "momio": {"game": {"local_team": {"name": "Masachapa", "sport": {"name": "soccer"}}, "visit_team": {"name": "'San Marcos", "sport": {"name": "soccer"}}, "final_score": "2-0", "winner_team": {"name": "Masachapa", "sport": {"name": "soccer"}}}, "bet_type": "Moneyline", "local_momio": 2.0, "visit_momio": 1.0, "draw_momio": 0.0}, "chosen_team": {"name": "Masachapa", "sport": {"name": "soccer"}}, "bet_amount": 10.0, "status": "Win", "total_profit": 20.0, "net_profit_amount": 10.0, "rationale": "Va a ganar el Masachapa FC por que es local", "bet_id": "ee31d060-7d40-4541-8bb7-fe0541adb51f"}, {"username": "jaslin", "momio": {"game": {"local_team": {"name": "Spain", "sport": {"name": "soccer"}}, "visit_team": {"name": "'Argentina", "sport": {"name": "soccer"}}, "final_score": "1-0", "winner_team": {"name": "Spain", "sport": {"name": "soccer"}}}, "bet_type": "Moneyline", "local_momio": 2.0, "visit_momio": 1.0, "draw_momio": 0.0}, "chosen_team": {"name": "Argentina", "sport": {"name": "soccer"}}, "bet_amount": 5.0, "status": "Lose", "total_profit": 0.0, "net_profit_amount": 0.0, "rationale": "Argentina pasa por un buen momento este 2025", "bet_id": "fd7e676b-3972-4ddc-8e6b-addf37194ccb"}, {"username": "jaslin", "momio": {"game": {"local_team": {"name": "Boer", "sport": {"name": "baseball"}}, "visit_team": {"name": "'San Fernando", "sport": {"name": "baseball"}}, "final_score": "8-1", "winner_team": {"name": "Boer", "sport": {"name": "baseball"}}}, "bet_type": "Under", "local_momio": 1.0, "visit_momio": 3.0, "draw_momio": 4.0}, "chosen_team": {"name": "Boer", "sport": {"name": "baseball"}}, "bet_amount": 20.0, "status": "Win", "total_profit": 20.0, "net_profit_amount": 0.0, "rationale": "El Boer es el mejor equipo armado esta temporada 2025 en la liga profesional", "bet_id": "6338cb8f-1c6d-4298-8551-c10703e5caa7"}], "holdings": {"soccer": 15, "baseball": 20}, "strategy": "", "portfolio_value_time_series": [["2025-11-27 08:28:25", 100.0], ["2025-11-27 08:29:09", 120.0], ["2025-11-27 08:30:08", 120.0], ["2025-11-27 08:31:18", 115.0], ["2025-11-27 08:31:41", 115.0], ["2025-11-27 08:32:11", 135.0], ["2025-11-27 08:33:27", 135.0]], "total_portfolio_value": 135.0, "total_profit_loss": 35.0}
# ***Getting name:jaslin
# json_data: {"username": "jaslin", "initial_deposit": 100.0, "balance": 135.0, "bets": [{"username": "jaslin", "momio": {"game": {"local_team": {"name": "Masachapa", "sport": {"name": "soccer"}}, "visit_team": {"name": "'San Marcos", "sport": {"name": "soccer"}}, "final_score": "2-0", "winner_team": {"name": "Masachapa", "sport": {"name": "soccer"}}}, "bet_type": "Moneyline", "local_momio": 2.0, "visit_momio": 1.0, "draw_momio": 0.0}, "chosen_team": {"name": "Masachapa", "sport": {"name": "soccer"}}, "bet_amount": 10.0, "status": "Win", "total_profit": 20.0, "net_profit_amount": 10.0, "rationale": "Va a ganar el Masachapa FC por que es local", "bet_id": "ee31d060-7d40-4541-8bb7-fe0541adb51f"}, {"username": "jaslin", "momio": {"game": {"local_team": {"name": "Spain", "sport": {"name": "soccer"}}, "visit_team": {"name": "'Argentina", "sport": {"name": "soccer"}}, "final_score": "1-0", "winner_team": {"name": "Spain", "sport": {"name": "soccer"}}}, "bet_type": "Moneyline", "local_momio": 2.0, "visit_momio": 1.0, "draw_momio": 0.0}, "chosen_team": {"name": "Argentina", "sport": {"name": "soccer"}}, "bet_amount": 5.0, "status": "Lose", "total_profit": 0.0, "net_profit_amount": 0.0, "rationale": "Argentina pasa por un buen momento este 2025", "bet_id": "fd7e676b-3972-4ddc-8e6b-addf37194ccb"}, {"username": "jaslin", "momio": {"game": {"local_team": {"name": "Boer", "sport": {"name": "baseball"}}, "visit_team": {"name": "'San Fernando", "sport": {"name": "baseball"}}, "final_score": "8-1", "winner_team": {"name": "Boer", "sport": {"name": "baseball"}}}, "bet_type": "Under", "local_momio": 1.0, "visit_momio": 3.0, "draw_momio": 4.0}, "chosen_team": {"name": "Boer", "sport": {"name": "baseball"}}, "bet_amount": 20.0, "status": "Win", "total_profit": 20.0, "net_profit_amount": 0.0, "rationale": "El Boer es el mejor equipo armado esta temporada 2025 en la liga profesional", "bet_id": "6338cb8f-1c6d-4298-8551-c10703e5caa7"}], "holdings": {"soccer": 15, "baseball": 20}, "strategy": "Randmon", "portfolio_value_time_series": [["2025-11-27 08:28:25", 100.0], ["2025-11-27 08:29:09", 120.0], ["2025-11-27 08:30:08", 120.0], ["2025-11-27 08:31:18", 115.0], ["2025-11-27 08:31:41", 115.0], ["2025-11-27 08:32:11", 135.0], ["2025-11-27 08:33:27", 135.0]]}
# Randmon
# ***Getting name:lieserl
# json_data: {"username": "lieserl", "initial_deposit": 100.0, "balance": 160.0, "bets": [{"username": "lieserl", "momio": {"game": {"local_team": {"name": "Boer", "sport": {"name": "baseball"}}, "visit_team": {"name": "'Gigantes de Rivas", "sport": {"name": "baseball"}}, "final_score": "6-5", "winner_team": {"name": "Boer", "sport": {"name": "baseball"}}}, "bet_type": "Over", "local_momio": 3.0, "visit_momio": 2.0, "draw_momio": 1.0}, "chosen_team": {"name": "Boer", "sport": {"name": "baseball"}}, "bet_amount": 20.0, "status": "Win", "total_profit": 60.0, "net_profit_amount": 40.0, "rationale": "El Boer es el mejor equipo armado esta temporada 2025 en la liga profesional", "bet_id": "3802a905-cbe9-4ae5-a216-f4fddd6e13e7"}], "holdings": {"baseball": 60}, "strategy": "Optimistic", "portfolio_value_time_series": [["2025-11-27 08:28:25", 100.0], ["2025-11-27 08:29:28", 160.0]]}
# Optimistic
# ***Getting name:geli
# json_data: {"username": "geli", "initial_deposit": 100.0, "balance": 85.0, "bets": [{"username": "geli", "momio": {"game": {"local_team": {"name": "Lakers", "sport": {"name": "basketball"}}, "visit_team": {"name": "'Miami Heat", "sport": {"name": "basketball"}}, "final_score": "90-95", "winner_team": {"name": "'Miami Heat", "sport": {"name": "basketball"}}}, "bet_type": "Handicap", "local_momio": 7.0, "visit_momio": 6.0, "draw_momio": 5.0}, "chosen_team": {"name": "Lakers", "sport": {"name": "basketball"}}, "bet_amount": 15.0, "status": "Lose", "total_profit": 0.0, "net_profit_amount": 0.0, "rationale": "Los L.A Lakers tienen mejor equipo en el 2025", "bet_id": "1c8b916e-eb71-46e8-8d63-b34c1dde4e85"}], "holdings": {"basketball": -15}, "strategy": "Pessimistic", "portfolio_value_time_series": [["2025-11-27 08:28:25", 100.0], ["2025-11-27 08:29:54", 85.0]]}
# Pessimistic

# %%
jaslin.report()
# Out:
# '{"username": "Jaslin", "initial_deposit": 100.0, "balance": 300.0, "bets": [{"username": "Jaslin", "momio": {"game": {"local_team": {"name": "FC Barcelona", "sport": {"name": "soccer"}}, "visit_team": {"name": "Eintracht Frankfurt", "sport": {"name": "soccer"}}, "final_score": "", "winner_team": {"name": "", "sport": {"name": "soccer"}}}, "bet_type": "Moneyline", "local_momio": 2.0, "visit_momio": 1.0, "draw_momio": 0.0}, "chosen_team": {"name": "FC Barcelona", "sport": {"name": "soccer"}}, "bet_amount": 100.0, "status": "Pending", "total_profit": 0.0, "net_profit_amount": 0.0, "rationale": "Betting on Barcelona to win at home.", "bet_id": "a5bde9b4-8a3c-4824-ae2c-6b62bd110bd8"}, {"username": "Jaslin", "momio": {"game": {"local_team": {"name": "Atalanta", "sport": {"name": "soccer"}}, "visit_team": {"name": "Chelsea", "sport": {"name": "soccer"}}, "final_score": "", "winner_team": {"name": "", "sport": {"name": "soccer"}}}, "bet_type": "Moneyline", "local_momio": 2.5, "visit_momio": 1.0, "draw_momio": 0.0}, "chosen_team": {"name": "Atalanta", "sport": {"name": "soccer"}}, "bet_amount": 100.0, "status": "Pending", "total_profit": 0.0, "net_profit_amount": 0.0, "rationale": "Atalanta has had strong home performances and Chelsea is struggling with form.", "bet_id": "5ec13dd3-2fe7-4a33-8363-9a9863ec3b8a"}, {"username": "Jaslin", "momio": {"game": {"local_team": {"name": "Bayern Munich", "sport": {"name": "soccer"}}, "visit_team": {"name": "Sporting CP", "sport": {"name": "soccer"}}, "final_score": "", "winner_team": {"name": "", "sport": {"name": "soccer"}}}, "bet_type": "Moneyline", "local_momio": 1.8, "visit_momio": 1.0, "draw_momio": 0.0}, "chosen_team": {"name": "Bayern Munich", "sport": {"name": "soccer"}}, "bet_amount": 100.0, "status": "Pending", "total_profit": 0.0, "net_profit_amount": 0.0, "rationale": "Bayern is historically strong at home against Sporting CP.", "bet_id": "d255a84d-8f75-4a89-b42a-014392248da9"}, {"username": "Jaslin", "momio": {"game": {"local_team": {"name": "FC Barcelona", "sport": {"name": "soccer"}}, "visit_team": {"name": "Eintracht Frankfurt", "sport": {"name": "soccer"}}, "final_score": "", "winner_team": {"name": "FC Barcelona", "sport": {"name": "soccer"}}}, "bet_type": "Moneyline", "local_momio": 2.0, "visit_momio": 1.0, "draw_momio": 0.0}, "chosen_team": {"name": "FC Barcelona", "sport": {"name": "soccer"}}, "bet_amount": 100.0, "status": "Win", "total_profit": 200.0, "net_profit_amount": 100.0, "rationale": "Betting on Barcelona to win at home.", "bet_id": "a5bde9b4-8a3c-4824-ae2c-6b62bd110bd8"}], "holdings": {"soccer": 200}, "strategy": "", "portfolio_value_time_series": [["2025-11-27 18:30:38", 100.0], ["2025-11-27 18:32:37", 100.0], ["2025-11-27 18:32:37", 100.0], ["2025-11-27 18:32:40", 100.0], ["2025-11-27 18:37:05", 100.0], ["2025-11-27 18:38:37", 300.0], ["2025-11-27 18:45:20", 300.0]], "total_portfolio_value": 300.0, "total_profit_loss": 200.0}'

# %%
jaslin.list_transactions()
# Out:
# [{'username': 'jaslin',
#   'Sport': 'soccer',
#   'Momio': 'local(2.0) - visit(1.0)',
#   'Amount': 10.0,
#   'Teams': "local (Masachapa ) - visit('San Marcos))",
#   'Winner': 'Masachapa',
#   'Chosen': 'Masachapa',
#   'Status': 'Win',
#   'Rationale': 'Va a ganar el Masachapa FC por que es local'},
#  {'username': 'jaslin',
#   'Sport': 'soccer',
#   'Momio': 'local(2.0) - visit(1.0)',
#   'Amount': 5.0,
#   'Teams': "local (Spain ) - visit('Argentina))",
#   'Winner': 'Spain',
#   'Chosen': 'Argentina',
#   'Status': 'Lose',
#   'Rationale': 'Argentina pasa por un buen momento este 2025'},
#  {'username': 'jaslin',
#   'Sport': 'baseball',
#   'Momio': 'local(1.0) - visit(3.0)',
#   'Amount': 20.0,
#   'Teams': "local (Boer ) - visit('San Fernando))",
#   'Winner': 'Boer',
#   'Chosen': 'Boer',
#   'Status': 'Win',
#   'Rationale': 'El Boer es el mejor equipo armado esta temporada 2025 en la liga profesional'}]

# %%
from gamblers import Gambler

gambler = Gambler("Jaslin")

await gambler.get_account_report()
# Out:
# '{"username": "Jaslin", "initial_deposit": 100.0, "balance": 100.0, "bets": [{"username": "Jaslin", "momio": {"game": {"local_team": {"name": "Kairat Almaty", "sport": {"name": "soccer"}}, "visit_team": {"name": "Olympiacos", "sport": {"name": "soccer"}}, "final_score": "", "winner_team": {"name": "", "sport": {"name": "soccer"}}}, "bet_type": "Moneyline", "local_momio": 1.5, "visit_momio": 1.0, "draw_momio": 0.0}, "chosen_team": {"name": "Kairat Almaty", "sport": {"name": "soccer"}}, "bet_amount": 100.0, "status": "Pending", "total_profit": 0.0, "net_profit_amount": 0.0, "rationale": "Betting on Kairat Almaty to win at home against Olympiacos in the UEFA Champions League.", "bet_id": "38ee3956-412b-4dad-bc9c-13f5d3ca17e7"}, {"username": "Jaslin", "momio": {"game": {"local_team": {"name": "Kairat Almaty", "sport": {"name": "soccer"}}, "visit_team": {"name": "Olympiacos", "sport": {"name": "soccer"}}, "final_score": "", "winner_team": {"name": "", "sport": {"name": "soccer"}}}, "bet_type": "Moneyline", "local_momio": 1.5, "visit_momio": 1.0, "draw_momio": 0.0}, "chosen_team": {"name": "Kairat Almaty", "sport": {"name": "soccer"}}, "bet_amount": 100.0, "status": "Pending", "total_profit": 0.0, "net_profit_amount": 0.0, "rationale": "Betting on Kairat Almaty to win at home against Olympiacos in the UEFA Champions League.", "bet_id": "8004fd37-3a43-41e9-8aee-5010d97d0bbd"}, {"username": "Jaslin", "momio": {"game": {"local_team": {"name": "Bayern Munich", "sport": {"name": "soccer"}}, "visit_team": {"name": "Sporting CP", "sport": {"name": "soccer"}}, "final_score": "", "winner_team": {"name": "", "sport": {"name": "soccer"}}}, "bet_type": "Moneyline", "local_momio": 1.5, "visit_momio": 1.0, "draw_momio": 0.0}, "chosen_team": {"name": "Bayern Munich", "sport": {"name": "soccer"}}, "bet_amount": 100.0, "status": "Pending", "total_profit": 0.0, "net_profit_amount": 0.0, "rationale": "Betting on Bayern Munich to win at home against Sporting CP in the UEFA Champions League.", "bet_id": "3817b235-88fe-4692-bfc2-89a81da84d72"}], "holdings": {}, "strategy": "", "total_portfolio_value": 100.0, "total_profit_loss": 0.0}'

# %%
from agents import Runner,Agent,trace
from IPython.display import display, Markdown

instructions = "You are able to manage an account for a client, and answer questions about the account."
request = "My name is Jaslin and my account is under the name Jaslin. What's my balance and my holdings?"

params = {"command": "uv", "args": ["run", "bets_server.py"]}
model = "gpt-4o-mini"

async with MCPServerStdio(params=params, client_session_timeout_seconds=30) as mcp_server:
    agent = Agent(name="bet_manager", instructions=instructions, model=model, mcp_servers=[mcp_server])
    with trace("bet_manager"):
        result = await Runner.run(agent, request)
    display(Markdown(result.final_output))
# Out:
# Your account holds the following:
#
# - **Soccer Holdings**: 15
# - **Baseball Holdings**: 20
#
# If you need more details or have any other questions, let me know!

# %%
#Creamos las bd si no existen
import os
import sqlite3

# Delete existing database file if it exists
if os.path.exists("file:./memory/jaslin.db"):
    os.remove("file:./memory/jaslin.db")
if os.path.exists("file:./memory/lieserl.db"):
    os.remove("file:./memory/lieserl.db")
if os.path.exists("file:./memory/geli.db"):
    os.remove("file:./memory/geli.db")

# %%
from agents.mcp import MCPServerStdio

#tiene que existir jaslin.db
params = {"command": "npx","args": ["-y", "mcp-memory-libsql"],"env": {"LIBSQL_URL": "file:./memory/jaslin.db"}}

async with MCPServerStdio(params=params, client_session_timeout_seconds=30) as server:
    mcp_tools = await server.list_tools()

params = {"command": "npx","args": ["-y", "mcp-memory-libsql"],"env": {"LIBSQL_URL": "file:./memory/lieserl.db"}}

async with MCPServerStdio(params=params, client_session_timeout_seconds=30) as server:
    mcp_tools = await server.list_tools()

params = {"command": "npx","args": ["-y", "mcp-memory-libsql"],"env": {"LIBSQL_URL": "file:./memory/geli.db"}}

async with MCPServerStdio(params=params, client_session_timeout_seconds=30) as server:
    mcp_tools = await server.list_tools()

mcp_tools
# Out:
# [Tool(name='create_entities', title='Create new entities with observations', description='Create new entities with observations', inputSchema={'$schema': 'http://json-schema.org/draft-07/schema#', 'type': 'object', 'properties': {'entities': {'type': 'array', 'items': {'type': 'object', 'properties': {'name': {'type': 'string'}, 'entityType': {'type': 'string'}, 'observations': {'type': 'array', 'items': {'type': 'string'}}}, 'required': ['name', 'entityType', 'observations']}}}, 'required': ['entities']}, outputSchema=None, icons=None, annotations=None, meta=None),
#  Tool(name='search_nodes', title='Search for entities and their relations using text search with relevance ranking', description='Search for entities and their relations using text search with relevance ranking', inputSchema={'$schema': 'http://json-schema.org/draft-07/schema#', 'type': 'object', 'properties': {'query': {'type': 'string'}, 'limit': {'type': 'number'}}, 'required': ['query']}, outputSchema=None, icons=None, annotations=None, meta=None),
#  Tool(name='read_graph', title='Get recent entities and their relations', description='Get recent entities and their relations', inputSchema={'type': 'object', 'properties': {}}, outputSchema=None, icons=None, annotations=None, meta=None),
#  Tool(name='create_relations', title='Create relations between entities', description='Create relations between entities', inputSchema={'$schema': 'http://json-schema.org/draft-07/schema#', 'type': 'object', 'properties': {'relations': {'type': 'array', 'items': {'type': 'object', 'properties': {'source': {'type': 'string'}, 'target': {'type': 'string'}, 'type': {'type': 'string'}}, 'required': ['source', 'target', 'type']}}}, 'required': ['relations']}, outputSchema=None, icons=None, annotations=None, meta=None),
#  Tool(name='delete_entity', title='Delete an entity and all its associated data (observations and relations)', description='Delete an entity and all its associated data (observations and relations)', inputSchema={'$schema': 'http://json-schema.org/draft-07/schema#', 'type': 'object', 'properties': {'name': {'type': 'string'}}, 'required': ['name']}, outputSchema=None, icons=None, annotations=None, meta=None),
#  Tool(name='delete_relation', title='Delete a specific relation between entities', description='Delete a specific relation between entities', inputSchema={'$schema': 'http://json-schema.org/draft-07/schema#', 'type': 'object', 'properties': {'source': {'type': 'string'}, 'target': {'type': 'string'}, 'type': {'type': 'string'}}, 'required': ['source', 'target', 'type']}, outputSchema=None, icons=None, annotations=None, meta=None)]

# %%
from gamblers import Gambler

gambler = Gambler("Jaslin")

await gambler.run()
# Out:
# Error running gambler Jaslin: Max turns (3) exceeded

# %%
from agents.mcp import MCPServerStdio

params = {"command": "uv", "args": ["run", "bets_server.py"]}

async with MCPServerStdio(params=params, client_session_timeout_seconds=30) as server:
    mcp_tools = await server.list_tools()
mcp_tools
# Out:
# [Tool(name='get_holdings', title=None, description='Get the holdings of the given account name.\n\n    Args:\n        name: The name of the account holder\n    ', inputSchema={'properties': {'name': {'title': 'Name', 'type': 'string'}}, 'required': ['name'], 'title': 'get_holdingsArguments', 'type': 'object'}, outputSchema={'additionalProperties': {'type': 'integer'}, 'title': 'get_holdingsDictOutput', 'type': 'object'}, icons=None, annotations=None, meta=None),
#  Tool(name='place_bate', title=None, description="Place bet of the given account name.\n\n    Args:\n        name: The name of the account holder\n        sportname: The sport\n        local_team_name: The local team\n        visit_team: The visit team\n        local_momio_value local momio value\n        bet_amount bet amount\n        rationale: The rationale for the purchase and fit with the account's strategy\n    ", inputSchema={'properties': {'name': {'title': 'Name', 'type': 'string'}, 'sportname': {'title': 'Sportname', 'type': 'string'}, 'local_team_name': {'title': 'Local Team Name', 'type': 'string'}, 'visit_team_name': {'title': 'Visit Team Name', 'type': 'string'}, 'local_momio_value': {'title': 'Local Momio Value', 'type': 'number'}, 'bet_amount': {'title': 'Bet Amount', 'type': 'number'}, 'rationale': {'title': 'Rationale', 'type': 'string'}}, 'required': ['name', 'sportname', 'local_team_name', 'visit_team_name', 'local_momio_value', 'bet_amount', 'rationale'], 'title': 'place_bateArguments', 'type': 'object'}, outputSchema={'$defs': {'Game': {'properties': {'local_team': {'$ref': '#/$defs/Team'}, 'visit_team': {'$ref': '#/$defs/Team'}, 'final_score': {'title': 'Final Score', 'type': 'string'}, 'winner_team': {'$ref': '#/$defs/Team'}}, 'required': ['local_team', 'visit_team', 'final_score', 'winner_team'], 'title': 'Game', 'type': 'object'}, 'Momio': {'properties': {'game': {'$ref': '#/$defs/Game'}, 'bet_type': {'title': 'Bet Type', 'type': 'string'}, 'local_momio': {'title': 'Local Momio', 'type': 'number'}, 'visit_momio': {'title': 'Visit Momio', 'type': 'number'}, 'draw_momio': {'title': 'Draw Momio', 'type': 'number'}}, 'required': ['game', 'bet_type', 'local_momio', 'visit_momio', 'draw_momio'], 'title': 'Momio', 'type': 'object'}, 'Sport': {'properties': {'name': {'title': 'Name', 'type': 'string'}}, 'required': ['name'], 'title': 'Sport', 'type': 'object'}, 'Team': {'properties': {'name': {'title': 'Name', 'type': 'string'}, 'sport': {'$ref': '#/$defs/Sport'}}, 'required': ['name', 'sport'], 'title': 'Team', 'type': 'object'}}, 'properties': {'username': {'title': 'Username', 'type': 'string'}, 'momio': {'$ref': '#/$defs/Momio'}, 'chosen_team': {'$ref': '#/$defs/Team'}, 'bet_amount': {'title': 'Bet Amount', 'type': 'number'}, 'status': {'title': 'Status', 'type': 'string'}, 'total_profit': {'title': 'Total Profit', 'type': 'number'}, 'net_profit_amount': {'title': 'Net Profit Amount', 'type': 'number'}, 'rationale': {'title': 'Rationale', 'type': 'string'}, 'bet_id': {'title': 'Bet Id', 'type': 'string'}}, 'required': ['username', 'momio', 'chosen_team', 'bet_amount', 'status', 'total_profit', 'net_profit_amount', 'rationale', 'bet_id'], 'title': 'Bet', 'type': 'object'}, icons=None, annotations=None, meta=None)]
